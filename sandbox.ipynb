# %%
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils
from causallearn.utils.Dataset import load_dataset
from omegaconf import OmegaConf
from sklearn.metrics import roc_auc_score
from pathlib import Path
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import adj_matrix_to_tetrad_file as adj_tetrad
import os

base_path = "./data/csuite"
for root, dirs, files in os.walk(base_path):
    if "adj_matrix.csv" in files:
        adj_fpath = os.path.join(root, "adj_matrix.csv")
        true_adj = pd.read_csv(adj_fpath, header=None).to_numpy()
        adj_tetrad.convert_adj_matrix_to_tetrad_file(
            true_adj, Path(adj_fpath).with_name("tetrad.txt")
        )
# Out:
# Tetrad file written to data/csuite/csuite_cat_to_cts/tetrad.txt
# Tetrad file written to data/csuite/csuite_linexp/tetrad.txt
# Tetrad file written to data/csuite/csuite_cts_to_cat/tetrad.txt
# Tetrad file written to data/csuite/csuite_weak_arrows_binary_t/tetrad.txt
# Tetrad file written to data/csuite/csuite_large_backdoor/tetrad.txt
# Tetrad file written to data/csuite/csuite_mixed_simpson/tetrad.txt
# Tetrad file written to data/csuite/csuite_mixed_confounding/tetrad.txt
# Tetrad file written to data/csuite/csuite_large_backdoor_binary_t/tetrad.txt
# Tetrad file written to data/csuite/csuite_cat_collider/tetrad.txt
# Tetrad file written to data/csuite/csuite_lingauss/tetrad.txt
# Tetrad file written to data/csuite/csuite_nonlingauss/tetrad.txt
# Tetrad file written to data/csuite/csuite_symprod_simpson/tetrad.txt
# Tetrad file written to data/csuite/csuite_weak_arrows/tetrad.txt
# Tetrad file written to data/csuite/csuite_nonlin_simpson/tetrad.txt
# ...
